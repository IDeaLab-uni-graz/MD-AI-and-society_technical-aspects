# %% [markdown]
# # Python Basics 1

# %% [markdown]
# ## Learning Objectives
#
# * Understanding how different data types (see also slides [Data](https://janalasser.at/lectures/MD_KI/VO2_4_data/) from the lecture) are implemented in Python and being able to convert between data types.
# * Knowing the most important operators in Python and being able to apply them.
# * Being able to write simple loops to perform operations multiple times.
# * Being able to create lists and work with them.

# %% [markdown]
# ## Data types

# %% [markdown]
# Programming is nothing more than processing (reading, converting, outputting) data.
#
# In a program, data is considered as individual *values*. For example, when a program asks you to enter a number (or a name, an email address, or anything else), your program reads the keyboard input and stores the entered data as a *value* in the main memory (RAM). With the appropriate command, you can then, for example, display this value on the screen.

# %% [markdown]
# Run the next code cell. Don’t worry: you don’t need to understand exactly what is happening yet; the example is just meant to demonstrate input (How old are you?) -> processing (multiply the years by 365.25) -> output (print) of data.
#
# **Note**: If a black window covers the output, you can close it by pressing **esc**.

# %%
age_years = int(input("How old are you (years)? "))   # Input
age_days = age_years * 365.25                         # Calculation
print(f"You are approximately {age_days} days old.")  # Output

# %% [markdown]
# ### Every Value Has a Data Type
#
# Every value in Python has a specific data type, such as a number, string (text), or time. The data type is determined by how the value was entered (or processed). Unlike other languages, in Python it is not necessary to explicitly declare the type; Python automatically recognizes the type.
#
# ~~~
# 1              # Data type int
# 3.14           # Data type float
# 'MC AI'        # Data type str
# True           # Data type bool
# ~~~

# %% [markdown]
# The most important types for this course are: `int`, `float`, `bool`, and `str`.
#
# We can determine the data type of a value by calling the function `type()` (you will learn more about functions next week). Run the following code cells to try it out:

# %%
type(1)

# %%
type(3.14)

# %%
type('MC AI')

# %%
type(False)

# %% [markdown]
# ### The Numeric Data Types `int` and `float`
#
# The data type `int` (integer) represents a whole number, while the data type `float` represents a decimal number (floating-point number: float). Both types can, in principle, become arbitrarily large; their size is only limited by the available main memory.

# %%
type(12345)

# %%
type(3.14)

# %% [markdown]
# ### The Data Type `bool` (Boolean, Truth Value)
#
# This data type has only two values: `True` or `False` (note: the capital letter at the beginning is important!).

# %%
type(True)

# %%
type(False)

# %% [markdown]
# ### The Data Type `str` (String, Character Sequence)
#
# A string is a sequence of individual characters. We will go into more detail about this data type later. For now, just briefly: string values must be enclosed in quotation marks (in Python, it doesn’t matter whether you use single or double quotes).

# %%
type('abc')

# %%
type("abc")

# %% [markdown]
# Since strings can be enclosed in either single or double quotes, you can use the other type as normal characters within the string:

# %%
print('"That is convenient," he said, "because you can use the other type of quotation mark within the string."')

# %% [markdown]
# **Note**: `print()` is another function that can be used to display something in the notebook. So far, we have only dealt with cells that perform a single operation, in which case the result of the operation is displayed automatically. However, if a cell contains multiple operations, only the last one is displayed automatically. To display the result of an earlier operation in the cell, we need to use `print()`.

# %%
type(1)
type(3.14)
type('abc')

# %%
print(type(1))
print(type(3.14))
print(type('abc'))

# %% [markdown]
# ### Why are data types important?

# %% [markdown]
# The data type determines how a value is represented internally.
#
# From a programmer’s perspective, the most important thing is what you **can** and **cannot** do with a particular data type.
# For example, the `upper()` method of the string type converts all characters to uppercase.

# %%
"abc".upper()

# %% [markdown]
# Using `upper()` with integers, on the other hand, doesn’t make sense and will result in an error:

# %%
123.upper()

# %% [markdown]
# Operators, such as mathematical operations, behave differently for different data types:

# %%
1 + 1

# %%
'abc' + 'def'

# %%
1 + '1' # results in a "Type Error"

# %% [markdown]
# ## Variables
#
# Variables are names for values. A variable is thus a name (which we define ourselves) that points to a specific value. This allows us to refer to that value in different parts of the program using its name. This is useful because we can create a value in one place and work with it in other places.

# %% [markdown]
# ### Assigning values

# %%
firstname = 'Jana'

# %% [markdown]
# Later in the program, we can use this variable to access the value. In the following example, to display it:

# %%
print(firstname)

# %% [markdown]
# ### Variables Are Variable
# As the name suggests, a variable can be assigned a new value any number of times during the program’s execution.

# %%
firstname = 'Wolfgang Amadeus'
print(firstname)
firstname = 'Ludwig'
print(firstname)

# %% [markdown]
# Here, we first assigned the value `Wolfgang Amadeus` to the variable `firstname` and later in the program the new value `Ludwig`. From that point on, the variable `firstname` refers to the new value.

# %% [markdown]
# ### Variables and Non-Values
#
# Python has a special data type `NoneType`, which can take exactly one value: `None`.

# %%
type(None)

# %% [markdown]
# `None` is a non-value used wherever no value is present. For example, a variable can be initialized with the value `None` and only later in the program be assigned a different value.
# If you want to check whether a variable’s value is `None`, you should use the `is` operator:

# %%
firstname = None   # Zuweisung
firstname is None  # Vergleich

# %% [markdown]
# ## Operators

# %% [markdown]
# ### Mathematical operators

# %% [markdown]
# Operators apply operations to values. That is, they do something with one or more values. In the first part of today’s session, we already covered the mathematical operators `+`, `-`, `*`, and `/`.
#
# In addition, there are the following mathematical operators:
#
# * `**`: Exponentiation (e.g., `2 ** 8` represents 2 to the power of 8)
# * `%`: Modulo (remainder of a division; e.g., `5 % 2` is 1)

# %% [markdown]
# ### Comparison Operators
#
# Comparison operators are used to compare two values.
#
# For example, you can check whether two values are equal. The corresponding operator is `==` (two equal signs!). Every comparison returns a truth value (i.e., `True` or `False`).
#
# ~~~
# 123 == 123
# True
#
# 'Graz' == 'Vienna'
# False
# ~~~
#
# Of course, you can also compare calculated values with each other:
#
# ~~~
# 100 / 4 == 75 / 3
# ~~~

# %% [markdown]
# Python has a number of comparison operators:
#
# * `==` returns `True` if the two values are equal
# * `!=` returns `True` if the two values are not equal
# * `<` returns `True` if the left value is less than the right value
# * `<=` returns `True` if the left value is less than or equal to the right value
# * `>` returns `True` if the left value is greater than the right value
# * `>=` returns `True` if the left value is greater than or equal to the right value

# %% [markdown]
# <font color='blue'><b>Exercise Operators</b></font>
# <ol class="outside">
# <li><font color='blue'>
# What is the remainder when 481 is divided by 17?</font></li>
# <li><font color='blue'>What happens when you add a float value to an integer value? What data type does the result have?</font></li>
# <li><font color='blue'>For each of the following expressions, first think about whether it will return True or False. Then try it directly here in the notebook!</font></li>
# </ol>

# %%
# Your code here

# %%
# 3.
'abc' != 'def'

# %%
'abc' == 'def'

# %%
5 > 4

# %%
7 <= 7

# %%
'a' < 'b'

# %% [markdown]
# If you are confused by the last example: In Python, `<`, `>`, `<=`, and `>=` can also be applied to strings. The comparison is based on their lexicographical (alphabetical) order, which is why `a` is considered less than `b`. Feel free to try this with longer strings as well!

# %% [markdown]
# ### Additional Assignment Operators
#
# We have already learned about the assignment operator `=` with variables:
#
# ~~~
# score = 77
# ~~~
#
# On the right-hand side, we can also use an expression:

# %%
score = 77 + 17
print(score)

# %% [markdown]
# Of course, it is also possible to use variables in the expression:

# %%
counter = 0
counter = counter + 1
print(counter)

# %% [markdown]
# ## Loops
#
# When programming, it is often necessary to repeat one or more statements, for example, for each element of a sequence (e.g., for each character in a string). For this purpose, the `for` loop is ideal.

# %% [markdown]
# ### The for Loop
#
# The `for` loop iterates element by element through a data type consisting of multiple elements and applies the code in the *body of the loop* to each element. The loop automatically ends when there are no more elements left.
#
# In the following example, we use a `for` loop to print each character of a string in order. After the last character, the loop ends.

# %%
sentence = "I am a horse."

for i in sentence:
    print(i)

# %% [markdown]
# This construct (`for element in sequence`) works for all data types that can provide one element after another. These are called **iterables**. Python has many such iterables. Using this, you can not only iterate through the characters of a string, but also through the elements of a list, the lines of a file, or simply through a sequence of numbers:

# %%
# The range function generates an object that provides numbers in order
# from a specific range: here from 1 (inclusive) to 11 (exclusive)
# We will learn exactly what a function is next week

for i in range(1, 11):
    print(i)

# %% [markdown]
# <font color='blue'><b>Exercise Loops - 1</b></font>
# <font color='blue'>
# Use a loop to calculate the sum of all numbers between 1 and 50,000</font>

# %%
# Your code here

# %% [markdown]
# <font color='purple'><b>Optional (Advanced) // Exercise Iterables </b></font>
# <ol class="outside">
# <font color='purple'>
# <li>Try to loop through the following large integer (6763459275) to print each number separately. What happens?</li>
# <li>Is there a way you can still loop through the integer printing every number? <b>Hint</b>: Convert the integer to another data type (i.e., iterable) that allows you to loop through.</li></font>
# </ol>

# %%
# Your code here

# %% [markdown]
# ### Indentation
#
# Here we have seen for the first time a peculiarity of Python that can sometimes be confusing: logically related blocks are indicated by indentation.
#
# ~~~
# for i in range(1, 11):
#     print(i)
# ~~~
#
# The colon at the end of the first line and the indentation of `print(i)` tell the interpreter that this is the loop body, i.e., the statement(s) to be executed in each iteration of the loop.
#
# An indentation of 4 spaces or one tab is recommended, but in principle, any number of spaces will work.

# %% [markdown]
# ### Loop Counter
#
# Sometimes, in addition to the values, you also need a running counter, i.e., the number of the current iteration. A simple way to achieve this is by defining a variable `i` that is used as a counter and is incremented by 1 in each iteration of the loop.
#
# Here is an example of a loop with a counter:

# %%
i = 0

for j in range(50, 60):
    print(i, j)

    i = i + 1

# %% [markdown]
# The same can be achieved more elegantly using the built-in `enumerate()` function:

# %%
for i, j in enumerate(range(50, 60)):
    print(i, j)

# %% [markdown]
# `enumerate(iterable)` provides two values for each iteration of the loop:
#
# * the counter (i.e., the current iteration number, starting at 0)
# * the actual value from the iterable

# %% [markdown]
# ### Nested Loops
# You can nest two (or more) loops inside each other (though more than two is usually not recommended, as it can produce a huge number of iterations). This allows, for example, combining all elements from two sequences. For loop counters, the variable names `i`, `j`, and `k` are commonly used (and should be used only as counters!).

# %%
for i in range(1, 11):
    for ii in range(1, 11):
        # print(f'{j} x {i} = {i*j}')
        print(i * ii)

# %% [markdown]
# **Note**: Here we have used a so-called formatted string, or "f-string." This is a string (i.e., a sequence of characters) in which we can dynamically insert the values of various variables at positions indicated by `{}`. You can learn more about f-strings on [this page](https://www.geeksforgeeks.org/python/formatted-string-literals-f-strings-python/) in the subsection "f-Strings."

# %% [markdown]
# <font color='blue'><b>Exercise Loops - 2</b></font>
# <font color='blue'>Think through step by step what happens during the execution of the nested loop.</font>

# %% [markdown]
# **Note**: The ability to visualize what happens during program execution is essential! So, from now on try to always anticipate what will happen in your program.

# %% [markdown]
# ## Lists

# %% [markdown]
# A list is an ordered sequence of elements.
# You can think of a list as a container that holds other objects in a specific order. A list (`list`) is thus, after strings (`str`), another *sequence type* that we will get to know.
#
# The data type of a list element does not matter; in other words, a list can store elements of any type:

# %%
# A list of four strings
students = ['Otto', 'Anna', 'Maria', 'Franz']
students

# %%
# A list of four floats
temperatures = [25.4, 28.1, 20.9, 26.0, 32.6]
temperatures

# %%
# A list of seven integers
grades = [1, 2, 1, 4, 3, 3, 2]
grades

# %% [markdown]
# A list can even contain elements of different types (though this is usually not a particularly good idea):

# %%
values = ['Otto', 7, True, 3.14]
values

# %% [markdown]
# ### Determining the Number of List Elements
# We can determine the number of elements in a list using the `len()` function:

# %%
len(students)

# %% [markdown]
# ### Accessing Individual Elements
# We can access a single element of a list using its **index**:

# %%
students[0]

# %% [markdown]
# This also works with negative index values!

# %%
students[-1]

# %% [markdown]
# ### Slicing
# In addition, sublists can be extracted:

# %%
students

# %%
students[1:3]

# %% [markdown]
# ### Iterating Through a List
#
# Using a `for` loop, we can go through the individual elements of a list, just as we did earlier for the individual characters of a string:

# %%
for stud in students:
    print(stud)

# %% [markdown]
# <font color='blue'><b>Exercise Lists - 1</b></font>
# <ul class="outside">
# <li><font color='blue'>Create a list of the last 5 meals you have eaten. Come up with a good variable name for this list.</font></li>
# <li><font color='blue'>Print the last 3 meals, each on its own line. The output should look something like this:</font></li>
# </ul>
#
# <font color='blue'>
# Doner<br>
# Pizza<br>
# Curry<br>
# </font>

# %%
# Your code here

# %% [markdown]
# ### Adding Elements
# We can add new elements to a list at any time. The method `append(VALUE)` adds a new element to the end of the list:

# %%
students = ['Otto', 'Anna', 'Maria', 'Franz']
print(students)
students.append('Otto')
print(students)

# %% [markdown]
# If needed, we can insert an element at any position. To do this, we use the `insert()` method of the `list` object. This method expects 2 parameters:
#
# 1. The position at which the value should be inserted into the list. This is 0-based, so position `0` means "at the very beginning," `1` means "after the first element."
# 2. The value to be inserted.

# %%
students.insert(0, 'Berta')
students

# %% [markdown]
# ### Removing Elements
#
# Similarly, we can remove elements. The `pop()` method removes the last element of the list. `pop()` also returns the value of the removed element.

# %%
last_stud = students.pop()
print(last_stud)
print(students)

# %% [markdown]
# However, `pop()` can also be called with an optional argument: a number corresponding to the index of the element to be removed:

# %% [markdown]
# <font color='blue'><b>Exercise Lists - 2</b></font>
# <font color='blue'>Imagine you just finished a meal.</font>
# <ul class="outside">
# <li><font color='blue'>Append the meal you just had to the end of the list you created in <b>Exercise Lists - 1</b>.</font></li>
# <li><font color='blue'>Remove the oldest meal so that the list again contains exactly 5 entries.</font></li>
# </ul>

# %%
# Your code here

# %% [markdown]
# ### Replacing Elements
# Using the index, the value of a list element can be changed at any time:

# %%
students = ['Otto', 'Anna', 'Maria', 'Franz']
print(students)
students[1] = 'Berta'
print(students)

# %% [markdown]
# Here, we have changed the value of the second element from 'Anna' to 'Berta'.

# %% [markdown]
# ### Performing Calculations with List Values
#
# For lists containing numerical values (`int`, `float`), Python provides functions that can be applied to all values in a list:
#
# * `max(list)` returns the largest value in the list
# * `min(list)` returns the smallest value in the list
# * `sum(list)` returns the sum of all values in the list

# %%
values = [7, 2, 4, 1, 4, 8, 4]
print("Largest value: {}".format(max(values)))
print("Smallest value: {}".format(min(values)))
print("Sum: {}".format(sum(values)))

# %%
for i, j, k in zip([1,2,3], [4, 5, 6], [7, 8, 9]):
  print(i, j, k)

# %% [markdown]
# ## Additional Materials

# %% [markdown]
# * **Data Types**: [Introduction to Data Types](https://www.geeksforgeeks.org/python/python-data-types/) from "Geeks for Geeks".
# * **Variables**: [Introduction to Variables](https://www.geeksforgeeks.org/python/python-variables/) from "Geeks for Geeks".
# * **Strings**: [Introduction to Strings](https://www.geeksforgeeks.org/python/python-string/) from "Geeks for Geeks".
# * **Operators**: [Introduction to Operators](https://www.geeksforgeeks.org/python/python-operators/) from "Geeks for Geeks".
# * **Loops**: [Introduction to Loops](https://www.geeksforgeeks.org/python/loops-in-python/) from "Geeks for Geeks".
# * **Lists**: [Introduction to Lists](https://www.geeksforgeeks.org/python/python-lists/) from "Geeks for Geeks".

# %% [markdown]
# ## Homework
#
# The homework for this part of the course can be found in [this notebook](https://colab.research.google.com/drive/1S910b75_-ycFSKEnQM2sSz5RJm0z3SAw?usp=sharing).

# %% [markdown]
# ## Source and License
#
# This notebook is largely based on content from the course [Fundamentals of Programming](https://github.com/gvasold/gdp/tree/main) by [Gunter Vasold](https://online.uni-graz.at/kfu_online/visitenkarte.show_vcard?pPersonenGruppe=3&pPersonenId=036149BE966ADC08). Modifications were made by Jana Lasser.
#
# The notebook may be used, modified, and redistributed under the terms of the [CC BY-NC-SA 4.0](https://creativecommons.org/licenses/by-nc-sa/4.0) license.
#
# This notebook was translated from German using GPT-5 and cross-checked by Alina Herderich.
