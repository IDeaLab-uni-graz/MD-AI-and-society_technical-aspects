# %% [markdown]
# # Homework for Session 2

# %% [markdown]
# The tasks presented here refer to the contents of the notebooks [Python Basics 2](https://colab.research.google.com/drive/1ilDuEgJckWqD1L57f1mfrY6xTYlDHiX1?usp=sharing) and [Python Basics 3](https://colab.research.google.com/drive/1GRXGsLI1_wsKpZOQlzJIAkXF-jGc7onI?usp=sharing).
#
# Remember: **In order for the changes you make to the notebook to be saved, you must first save the notebook for yourself. To do this, go to `File` - `Save a copy in Drive`.** If you are using a local Python installation, download the notebook before making any changes.

# %% [markdown]
# ## Conditions

# %% [markdown]
# ### Exercise Conditions 1
#
# Write a program that checks whether a number is even or odd.
# **Note**: The modulo operator `%` can be used to perform "division with remainder". The "remainder" of the division is returned.

# %% [markdown]
# ### Exercise Conditions 2
#
# Write a program that checks whether a word contains the letter 'e' and is shorter than 5 letters.

# %% [markdown]
# ### Exercise Conditions 3
#
# Create a variable called `price`. Assign this variable any integer value. Then write an `if ... elif ... elif ... else` cascade that produces the following outputs for the value of `price`:
#
# * If `price > 10`, output `acceptable`.
# * If `price > 20`, output `expensive`.
# * If `price > 30`, output `very expensive`.
# * In all other cases, output `cheap`.
#
# Try out your conditions with different values for `price`.

# %% [markdown]
# ### Exercise Conditions 4
#
# * Create a list with the numbers from 0 to 20.
#
# **Note**: Use the `range()` function that you learned about in the first course unit.
#
# * Write a program that iterates over the created list using a `for` loop and:
#
#   * multiplies all numbers smaller than 10 by 2 and prints them,
#   * divides all numbers greater than 10 by 2 and prints them, and
#   * includes a special case for the number 15 that outputs a warning when this number is reached.

# %% [markdown]
# ### Exercise Conditions 5
#
# Use the `in` operator to check whether the name `Alfons` is included in the name list below.
# **Note**: You need to run the cell with the name list once so that the variable containing the name list is recognized in the notebook.

# %%
names = [
    "Astrid", "Ines", "Christoph", "Markus", "Çınar", "Đželila", "Niklas",
    "Anna", "Stefanie", "Raphael", "Anna-Lena", "Silvia", "Julian", "Simon",
    "Katharina", "Michael", "Dominik", "Maria", "Kevin", "Bianca", "Thomas",
    "Nora", "Manuel", "Selina", "Gabriel", "Daniel", "Thomas", "Nina", "Michael",
    "Fabio", "Theresa", "Manuel", "Carina", "Philipp", "Lukas", "Wolfgang",
    "Anna", "Doris", "Thomas", "Muhammed", "Christoph", "Lisa-Marie", "Jessica",
    "Maria", "Thomas", "Florian", "Martin", "Anna", "Oliver", "Gregor", "Helmut",
    "Florian", "Matteo", "David", "Marlene", "Vanessa", "Lea", "Jan", "Béla",
    "Verena", "Manuel", "Björn", "Tobias", "Denise", "Emma", "Lukas", "Sarah",
    "Oliver", "Janine", "Manuel", "Georg", "Lorenz", "Verena", "Caroline",
    "Laura", "Felix", "Simon", "Lea", "Peter", "Sandra", "Julia", "Sophie",
    "Jacqueline", "Nina", "Sebastian", "David", "Matthias", "Patrick", "Selina",
    "Fabian", "Daniel", "Sabine", "Josef", "Lisa", "Carina", "Florian", "Fabian",
    "Viktoria", "Christoph", "Emilia"
]

# %% [markdown]
# ## Functions

# %% [markdown]
# ### Exercise Functions 1
#
# Write a function that takes two numbers as arguments and outputs their sum, difference, product, and quotient. Test the function with different pairs of numbers.

# %% [markdown]
# ### Exercise Functions 2
#
# Modify the function written in "Exercise Functions 1" so that one of the two parameters always has a default value of 10.

# %% [markdown]
# ### Exercise Functions 3
#
# Provide the function you wrote above with a meaningful description using a docstring. Display the docstring using the help function <tt>?function_name</tt>.

# %% [markdown]
# ## Data

# %%
# For preparation, we will again load the dataset with
# Titanic passengers
import seaborn
titanic_data = seaborn.load_dataset("titanic")
titanic_data.head()

# %%
first_class = titanic_data[titanic_data["class"] == "First"]
first_class.head()

# %% [markdown]
# ### Exercise Data 1
#
# In the code above, the DataFrame was filtered so that only first-class passengers were selected. The filtered dataset was stored in the variable `first_class`.
#
# * Also filter out the second- and third-class passengers and store the filtered DataFrames in their own variables `second_class` and `third_class`.
# * What was the survival probability of passengers in the first, second, and third class?
# * What was the average ticket price (column `fare`) in the first, second, and third class?
#
# **Note:** The column `survived` indicates whether a passenger survived. Calculating the mean of this column gives the survival probability.

# %% [markdown]
# ### Exercise Data 2
#
# * Now filter the DataFrame so that only female or male passengers are selected. Store the filtered datasets in their own variables.
# * What was the survival probability of women and men?

# %% [markdown]
# ### Exercise Data 3

# %%
len(titanic_data["deck"].dropna())

# %%
len(titanic_data)

# %%
passengers_with_deck = titanic_data.dropna(subset=['deck'])

# %% [markdown]
# For many passengers, the deck is not known. In the code above, passengers without deck information were discarded. The function `dropna()` was used for this, with the column specified (`subset=['deck']`).
#
# * How many passengers remain after filtering?
# * Find out which decks existed on the Titanic.
# * Which deck had the highest survival probability?

# %% [markdown]
# ## Source and License
#
# This notebook was created by Jana Lasser for Course B "Technical Aspects" of the Microcredential "AI and Society" at the University of Graz.
#
# The notebook can be used, modified, and redistributed under the terms of the [CC BY-NC-SA 4.0](https://creativecommons.org/licenses/by-nc-sa/4.0) license.
#
# This notebook was translated from German using GPT-5 and cross-checked by Alina Herderich.
